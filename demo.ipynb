# %%
from main import run_agent, memory

# %%
run_agent("Plan a route to visit Red Fort, India Gate, and Lotus Temple in Delhi.")
# Out:
# [Step 1] Thinking...
#   -> calling order_stops({'stops': ['Red Fort, Delhi', 'India Gate, Delhi', 'Lotus Temple, Delhi']})
#   -> result: ['Red Fort, Delhi', 'India Gate, Delhi', 'Lotus Temple, Delhi']
#
# [Step 2] Thinking...
#
# Final answer: Here’s a simple, efficient itinerary for visiting the three Delhi landmarks:
#
# 1. **Start at Red Fort** – explore this historic Mughal fortress.
# 2. **Drive to India Gate** (≈ 3 km, about 10 minutes). It’s a short hop south‑west, letting you see the iconic war memorial and the surrounding Rajpath area.
# 3. **Continue to Lotus Temple** (≈ 7 km, about 20 minutes). Head north‑west to the striking Baháʼí House of Worship, where you can relax in its tranquil gardens.
#
# This order minimizes back‑tracking and keeps the total driving distance to roughly 10 km, making for a smooth half‑day tour of Delhi’s top sights. Safe travels!
# ...

# %%
run_agent("Add Qutub Minar Delhi to today's plan, starting from Red Fort Delhi.")
# Out:
# [Step 1] Thinking...
#   -> calling order_stops({'stops': ['Red Fort, Delhi', 'India Gate, Delhi', 'Lotus Temple, Delhi', 'Qutub Minar, Delhi']})
#   -> result: ['Red Fort, Delhi', 'India Gate, Delhi', 'Lotus Temple, Delhi', 'Qutub Minar, Delhi']
#
# [Step 2] Thinking...
#
# Final answer: Here’s an efficient order for your day, beginning at Red Fort:
#
# 1. **Red Fort, Delhi** – start here as requested.
# 2. **India Gate, Delhi** – a short drive south‑west from the fort.
# 3. **Lotus Temple, Delhi** – head further west to this iconic structure.
# 4. **Qutub Minar, Delhi** – finish with the historic tower in the south‑west part of the city.
#
# This route minimizes back‑tracking while letting you enjoy each landmark in a logical sequence. Safe travels!
# ...

# %%
memory.summary()
# Out:
# {'visited_so_far': ['Red Fort, Delhi',
#   'India Gate, Delhi',
#   'Lotus Temple, Delhi',
#   'Qutub Minar, Delhi'],
#  'planned_route': ['Red Fort, Delhi',
#   'India Gate, Delhi',
#   'Lotus Temple, Delhi',
#   'Qutub Minar, Delhi'],
#  'goals_handled': 2}

# %%
from main import run_agent, memory

# %%
run_agent("Plan a route to visit Roorkee, Shimla, and Mandi.")
# Out:
# [Step 1] Thinking...
#   -> calling order_stops({'stops': ['Roorkee', 'Shimla', 'Mandi']})
#   -> result: ['Roorkee', 'Shimla', 'Mandi']
#
# [Step 2] Thinking...
#
# Final answer: Here’s an efficient order for your trip:
#
# **Roorkee → Shimla → Mandi**
#
# This sequence moves north‑west from Roorkee to Shimla, then continues further north‑west to Mandi, minimizing backtracking and overall travel distance. Safe travels!
# 'Here’s an efficient order for your trip:\n\n**Roorkee → Shimla → Mandi**\n\nThis sequence moves north‑west from Roorkee to Shimla, then continues further north‑west to Mandi, minimizing backtracking and overall travel distance. Safe travels!'
